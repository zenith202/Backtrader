# %%
# TODO: Determine position size: Dollar Volatility = N × Dollars per Point. Unit = 1% of porfolio / Dollar Volatility
# TODO: Reduce trading size when account amount decreases (10% overall decrease -> 20% trading amount decrease), reinstate when back to initial starting amount
# TODO: Implement System 2
# TODO: Ignoring breakouts (System 1) as previous one was a winner (regardless of long or short), failsafe is System 2 entry (System 2 does not have this breakout filter). Implemented, but need to check CORRECTNESS
# Implemented: System 1 Longs, pyramiding up to 5 additional orders (1/2 N increments)
# Implemented: fixed selling over multiple orders (observation: some work better when selling over a period of time vs all at once)
# Implemented: both longs and shorts can be executed (Need to run tests to verify it's working properly)

from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt

# Close all the positions of this particular stock
def closeAllPositions(self):
    for data in self.datas:
        size = self.getposition(data).size
        if  size != 0:
            self.order = self.close(data)

# already have position in the market, check if we can pyramid, take profit, or execute a stop loss
def longPosition(self):
    # Calculate the 2N stop loss based on the previous atr
    N = self.atr[-1]
    stop2N = self.previousOrder - 2 * N
    pyramidHalfN = self.previousOrder + 1/2 * N
    

    # in the market, see if we can pyramid our position
    if self.pyramid < 5 and self.dataopen[0] > pyramidHalfN:
        # BUY, BUY, BUY!!! (with default parameters)
        self.log('BUY CREATE PYRAMID, current open price: %.2f' % self.dataopen[0])
        self.log('N value: %.2f' % self.atr[-1])
        self.log('Pyramid: %.2f' % self.pyramid)
        self.log('N buy in price: %.2f' % pyramidHalfN)
        self.pyramid += 1
        # Keep track of the created order to avoid a 2nd order
        self.order = self.buy()
        self.log('New previousOrder, should be same as BUY EXECUTED: %.2f' % self.previousOrder)
        
    # Already in the market ... we might sell
    if self.s1ExitLong[-1] > self.dataopen[0]:
        # SELL, SELL, SELL!!! (with all possible default parameters)
        # Below system low exit price
        self.log('SELL CREATE, 10 day low: %.2f' % self.s1ExitLong[-1])
        self.log('exit low: %.2f' % self.dataopen[0])
        # Keep track of the created order to avoid a 2nd order
        self.pyramid = 0
        closeAllPositions(self)
                
    # current price has dropped below our 2N stop
    # close all open positions of this stock
    elif self.dataopen[0] < stop2N:
        # Below 2N stop
        stopPrice = stop2N
        self.log('___________SELL CREATE, N stop: %.2f' % stopPrice)
        self.log('Current Price: %.2f' % self.dataopen[0])
        self.log('N value: %.2f' % self.atr[-1])
        # Keep track of the created order to avoid a 2nd order
        self.pyramid = 0
        closeAllPositions(self)

# track longs to mark and see if it is a winner, mainly to set the winner flag
def trackLongPosition(self):
    N = self.atr[-1]
    stop2N = self.previousOrder - 2 * N
    pyramidHalfN = self.previousOrder + 1/2 * N
    # Already in the market ... we might sell
    if self.s1ExitLong[-1] > self.dataopen[0]:
        # SELL, SELL, SELL!!! (with all possible default parameters)
        # Below system low exit price
        self.log('tracking:_______SELL TRACK, 10 day low: %.2f' % self.s1ExitLong[-1])
        self.log('exit low: %.2f' % self.dataopen[0])
        # Keep track of the created order to avoid a 2nd order
        self.pyramid = 0
        self.winner = False
                
    elif self.dataopen[0] < stop2N:
        # Below 2N stop
        stopPrice = stop2N
        self.log('tracking:_______SELL TRACK, N stop: %.2f' % stopPrice)
        self.log('Current Price: %.2f' % self.dataopen[0])
        self.log('N value: %.2f' % self.atr[-1])
        # Keep track of the created order to avoid a 2nd order
        self.pyramid = 0
        self.winner = False

# already have position in the market, check if we can pyramid, take profit, or execute a stop loss
def shortPosition(self):
    N = self.atr[-1]
    stop2N = self.previousOrder + 2 * N
    pyramidHalfN = self.previousOrder - 1/2 * N
    # in the market, see if we can pyramid our position
    if self.pyramid < 5 and self.dataopen[0] < pyramidHalfN:
        # BUY, BUY, BUY!!! (with default parameters)
        self.log('SELL CREATE PYRAMID, current open price: %.2f' % self.dataopen[0])
        self.log('N value: %.2f' % self.atr[-1])
        self.log('Pyramid: %.2f' % self.pyramid)
        self.log('N buy in price: %.2f' % pyramidHalfN)
        self.pyramid += 1
        # Keep track of the created order to avoid a 2nd order
        self.order = self.sell()
        self.log('New previousOrder, should be same as SELL EXECUTED: %.2f' % self.previousOrder)
        
    # Already in the market ... we might sell
    if self.s1ExitShort[-1] < self.dataopen[0]:
        self.log('BUY CREATE, 10 day high: %.2f' % self.s1ExitShort[-1])
        self.log('exit low: %.2f' % self.dataopen[0])
        # Keep track of the created order to avoid a 2nd order
        self.pyramid = 0
        closeAllPositions(self)
                
    elif self.dataopen[0] > stop2N:
        # Above 2N stop
        stopPrice = stop2N
        self.log('___________BUY CREATE, N stop: %.2f' % stopPrice)
        self.log('Current Price: %.2f' % self.dataopen[0])
        self.log('N value: %.2f' % self.atr[-1])
        # Keep track of the created order to avoid a 2nd order
        self.pyramid = 0
        closeAllPositions(self)

def trackShortPosition(self):
    N = self.atr[-1]
    stop2N = self.previousOrder + 2 * N
    pyramidHalfN = self.previousOrder - 1/2 * N
    # Already in the market ... we might sell
    if self.s1ExitShort[-1] < self.dataopen[0]:
        self.log('tracking:_______BUY TRACK, 10 day high: %.2f' % self.s1ExitShort[-1])
        self.log('exit low: %.2f' % self.dataopen[0])
        # Keep track of the created order to avoid a 2nd order
        self.pyramid = 0
        self.winner = False
                
    elif self.dataopen[0] > stop2N:
        # Above 2N stop
        stopPrice = stop2N
        self.log('tracking:_______SELL TRACK CREATE, N stop: %.2f' % stopPrice)
        self.log('Current Price: %.2f' % self.dataopen[0])
        self.log('N value: %.2f' % self.atr[-1])
        # Keep track of the created order to avoid a 2nd order
        self.pyramid = 0
        self.winner = False

# Create a Stratey
class TestStrategy(bt.Strategy):

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close", "open" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        self.dataopen = self.datas[0].open

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None
        self.long = None
        self.pyramid = 0
        self.previousOrder = self.dataopen
        self.totalNumberOfOrders = 0
        self.long = False
        self.winner = False
        
        # 20 day ATR for N value
        self.atr = bt.indicators.ATR(self.datas[0], period = 20)
        
        # System 1: 20 day entry, 10 day exit
        self.s1EntryLong = bt.indicators.Highest(period = 20)
        self.s1ExitLong = bt.indicators.Lowest(period = 10)

        self.s1EntryShort = bt.indicators.Lowest(period = 20)
        self.s1ExitShort = bt.indicators.Highest(period = 10)
        
        # System 2: 55 day entry, 20 day exit
        self.s2EntryLong = bt.indicators.Highest(period = 55)
        self.s2ExitLong = bt.indicators.Lowest(period = 20)

        self.s2EntryShort = bt.indicators.Lowest(period = 55)
        self.s2ExitShort = bt.indicators.Highest(period = 20)

        print(self.datas[0].head())

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
                self.previousOrder = order.executed.price
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('|||||||||||||||||OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))
        if trade.pnl > 0:
            self.winner = True
        else:
            self.winner = False

    def next(self):
        # Simply log the closing price of the series from the reference
        #self.log('Close, %.2f' % self.dataclose[0])
        self.log('Sanity Check, 20 day high %.2f' %self.s1EntryLong[-1])
        self.log('Sanity Check, 10 day high %.2f' %self.s1ExitShort[-1])
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.s1EntryLong[-1] < self.dataopen[0]:
                # Check if previous trade was a winner
                if self.winner:
                    # Only track the position, don't actually buy
                    trackLongPosition(self)
                else:
                    # BUY, BUY, BUY!!! (with default parameters)
                    self.log('BUY CREATE, %.2f' % self.dataopen[0])
                    self.log('entry high: %.2f' % self.s1EntryLong[-1])

                    # Keep track of the created order to avoid a 2nd order
                    self.order = self.buy()
                    self.long = True

            # we MIGHT SELL if ...
            elif self.s1EntryShort[-1] > self.dataopen[0]:
                # Check if previous trade was a winner
                if self.winner:
                    # Only track the position, don't actually buy
                    trackShortPosition(self)
                else:
                    self.log('SELL CREATE, %.2f' % self.dataopen[0])
                    # self.log('entry high: %.2f' % self.entry[-1])

                    # Keep track of the created order to avoid a 2nd order
                    self.order = self.sell()
                    self.long = False

        else:
            if self.long:
                longPosition(self)
            else:
                shortPosition(self)
           

if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname='/Users/Ziyi/Documents/backtrader/data/AAPL.csv', 
         fromdate=datetime.datetime(2018, 1, 1), 
         todate=datetime.datetime(2020, 6, 24),
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(100000.0)
    
    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission - 0.1% ... divide by 100 to remove the %
    cerebro.broker.setcommission(commission=0.001)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# <backtrader.feeds.yahoo.YahooFinanceCSVData object at 0x7fe77b18b550>
# 2018-03-21, Sanity Check, 20 day high 176.20
# 2018-03-21, Sanity Check, 10 day high 176.20
# 2018-03-22, Sanity Check, 20 day high 176.20
# 2018-03-22, Sanity Check, 10 day high 176.20
# 2018-03-22, SELL CREATE, 164.84
# 2018-03-23, SELL EXECUTED, Price: 163.28, Cost: -1632.80, Comm 1.63
# 2018-03-23, Sanity Check, 20 day high 176.20
# 2018-03-23, Sanity Check, 10 day high 176.20
# 2018-03-26, Sanity Check, 20 day high 176.20
# 2018-03-26, Sanity Check, 10 day high 176.20
# 2018-03-27, Sanity Check, 20 day high 176.20
# 2018-03-27, Sanity Check, 10 day high 174.51
# 2018-03-28, Sanity Check, 20 day high 176.20
# 2018-03-28, Sanity Check, 10 day high 173.23
# 2018-03-29, Sanity Check, 20 day high 176.20
# 2018-03-29, Sanity Check, 10 day high 173.23
# 2018-04-02, Sanity Check, 20 day high 176.20
# 2018-04-02, Sanity Check, 10 day high 172.62
# 2018-04-03, Sanity Check, 20 day high 176.20
# 2018-04-03, Sanity Check, 10 day high 169.98
# 2018-04-04, Sanity Check, 20 day high 176.20
# 2018-04-04, Sanity Check, 10 day high 169.92
# 2018-04-05, Sanity Check, 20 day high 176.20
# 2018-04-05, Sanity Check, 10 day high 167.53
# 2018-04-06, Sanity Check, 20 day high 176.20
# 2018-04-06, Sanity Check, 10 day high 167.56
# 2018-04-09, Sanity Check, 20 day high 176.20
# 2018-04-09, Sanity Check, 10 day high 167.56
# 2018-04-10, Sanity Check, 20 day high 176.20
# 2018-04-10, Sanity Check, 10 day high 167.56
# 2018-04-10, BUY CREATE, 10 day high: 167.56
# 2018-04-10, exit low: 167.75
# 2018-04-11, BUY EXECUTED, Price: 167.00, Cost: -1632.80, Comm 1.67
# 2018-04-11, |||||||||||||||||OPERATION PROFIT, GROSS -37.20, NET -40.50
# 2018-04-11, Sanity Check, 20 day high 174.51
# 2018-04-11, Sanity Check, 10 day high 167.99
# 2018-04-12, Sanity Check, 20 day high 173.23
# 2018-04-12, Sanity Check, 10 day high 167.99
# 2018-04-13, Sanity Check, 20 day high 173.23
# 2018-04-13, Sanity Check, 10 day high 168.85
# 2018-04-16, Sanity Check, 20 day high 172.62
# 2018-04-16, Sanity Check, 10 day high 169.43
# 2018-04-17, Sanity Check, 20 day high 170.48
# 2018-04-17, Sanity Check, 10 day high 170.48
# 2018-04-17, BUY CREATE, 171.13
# 2018-04-17, entry high: 170.48
# 2018-04-18, BUY EXECUTED, Price: 172.41, Cost: 1724.10, Comm 1.72
# 2018-04-18, Sanity Check, 20 day high 172.83
# 2018-04-18, Sanity Check, 10 day high 172.83
# 2018-04-19, Sanity Check, 20 day high 172.83
# 2018-04-19, Sanity Check, 10 day high 172.83
# 2018-04-20, Sanity Check, 20 day high 172.83
# 2018-04-20, Sanity Check, 10 day high 172.83
# 2018-04-23, Sanity Check, 20 day high 172.83
# 2018-04-23, Sanity Check, 10 day high 172.83
# 2018-04-23, ___________SELL CREATE, N stop: 164.84
# 2018-04-23, Current Price: 161.77
# 2018-04-23, N value: 3.78
# 2018-04-24, SELL EXECUTED, Price: 160.64, Cost: 1724.10, Comm 1.61
# 2018-04-24, |||||||||||||||||OPERATION PROFIT, GROSS -117.70, NET -121.03
# 2018-04-24, Sanity Check, 20 day high 172.83
# 2018-04-24, Sanity Check, 10 day high 172.83
# 2018-04-25, Sanity Check, 20 day high 172.83
# 2018-04-25, Sanity Check, 10 day high 172.83
# 2018-04-25, SELL CREATE, 157.68
# 2018-04-26, SELL EXECUTED, Price: 159.14, Cost: -1591.40, Comm 1.59
# 2018-04-26, Sanity Check, 20 day high 172.83
# 2018-04-26, Sanity Check, 10 day high 172.83
# 2018-04-26, SELL CREATE PYRAMID, current open price: 159.14
# 2018-04-26, N value: 3.75
# 2018-04-26, Pyramid: 0.00
# 2018-04-26, N buy in price: 170.54
# 2018-04-26, New previousOrder, should be same as SELL EXECUTED: 172.41
# 2018-04-27, SELL EXECUTED, Price: 159.02, Cost: -1590.20, Comm 1.59
# 2018-04-27, Sanity Check, 20 day high 172.83
# 2018-04-27, Sanity Check, 10 day high 172.83
# 2018-04-27, SELL CREATE PYRAMID, current open price: 159.02
# 2018-04-27, N value: 3.68
# 2018-04-27, Pyramid: 1.00
# 2018-04-27, N buy in price: 170.57
# 2018-04-27, New previousOrder, should be same as SELL EXECUTED: 172.41
# 2018-04-30, SELL EXECUTED, Price: 157.21, Cost: -1572.10, Comm 1.57
# 2018-04-30, Sanity Check, 20 day high 172.83
# 2018-04-30, Sanity Check, 10 day high 172.83
# 2018-04-30, SELL CREATE PYRAMID, current open price: 157.21
# 2018-04-30, N value: 3.67
# 2018-04-30, Pyramid: 2.00
# 2018-04-30, N buy in price: 170.57
# 2018-04-30, New previousOrder, should be same as SELL EXECUTED: 172.41
# 2018-05-01, SELL EXECUTED, Price: 161.36, Cost: -1613.60, Comm 1.61
# 2018-05-01, Sanity Check, 20 day high 172.83
# 2018-05-01, Sanity Check, 10 day high 172.83
# 2018-05-01, SELL CREATE PYRAMID, current open price: 161.36
# 2018-05-01, N value: 3.75
# 2018-05-01, Pyramid: 3.00
# 2018-05-01, N buy in price: 170.53
# 2018-05-01, New previousOrder, should be same as SELL EXECUTED: 172.41
# 2018-05-02, SELL EXECUTED, Price: 169.91, Cost: -1699.10, Comm 1.70
# 2018-05-02, Sanity Check, 20 day high 172.83
# 2018-05-02, Sanity Check, 10 day high 172.44
# 2018-05-02, SELL CREATE PYRAMID, current open price: 169.91
# 2018-05-02, N value: 3.75
# 2018-05-02, Pyramid: 4.00
# 2018-05-02, N buy in price: 170.53
# 2018-05-02, New previousOrder, should be same as SELL EXECUTED: 172.41
# 2018-05-03, SELL EXECUTED, Price: 170.54, Cost: -1705.40, Comm 1.71
# 2018-05-03, Sanity Check, 20 day high 172.83
# 2018-05-03, Sanity Check, 10 day high 171.21
# 2018-05-04, Sanity Check, 20 day high 172.83
# 2018-05-04, Sanity Check, 10 day high 171.52
# 2018-05-04, BUY CREATE, 10 day high: 171.52
# 2018-05-04, exit low: 172.84
# 2018-05-07, BUY EXECUTED, Price: 179.56, Cost: -9771.80, Comm 10.77
# 2018-05-07, |||||||||||||||||OPERATION PROFIT, GROSS -1001.80, NET -1022.35
# 2018-05-07, Sanity Check, 20 day high 178.25
# 2018-05-07, Sanity Check, 10 day high 178.25
# 2018-05-07, BUY CREATE, 179.56
# 2018-05-07, entry high: 178.25
# 2018-05-08, BUY EXECUTED, Price: 179.38, Cost: 1793.80, Comm 1.79
# 2018-05-08, Sanity Check, 20 day high 179.54
# 2018-05-08, Sanity Check, 10 day high 179.54
# 2018-05-09, Sanity Check, 20 day high 180.40
# 2018-05-09, Sanity Check, 10 day high 180.40
# 2018-05-10, Sanity Check, 20 day high 181.67
# 2018-05-10, Sanity Check, 10 day high 181.67
# 2018-05-10, BUY CREATE PYRAMID, current open price: 182.04
# 2018-05-10, N value: 3.90
# 2018-05-10, Pyramid: 0.00
# 2018-05-10, N buy in price: 181.33
# 2018-05-10, New previousOrder, should be same as BUY EXECUTED: 179.38
# 2018-05-11, BUY EXECUTED, Price: 184.45, Cost: 1844.50, Comm 1.84
# 2018-05-11, Sanity Check, 20 day high 184.27
# 2018-05-11, Sanity Check, 10 day high 184.27
# 2018-05-14, Sanity Check, 20 day high 184.27
# 2018-05-14, Sanity Check, 10 day high 184.27
# 2018-05-15, Sanity Check, 20 day high 184.27
# 2018-05-15, Sanity Check, 10 day high 184.27
# 2018-05-16, Sanity Check, 20 day high 184.27
# 2018-05-16, Sanity Check, 10 day high 184.27
# 2018-05-17, Sanity Check, 20 day high 184.27
# 2018-05-17, Sanity Check, 10 day high 184.27
# 2018-05-18, Sanity Check, 20 day high 184.27
# 2018-05-18, Sanity Check, 10 day high 184.27
# 2018-05-21, Sanity Check, 20 day high 184.27
# 2018-05-21, Sanity Check, 10 day high 184.27
# 2018-05-22, Sanity Check, 20 day high 184.27
# 2018-05-22, Sanity Check, 10 day high 184.27
# 2018-05-23, Sanity Check, 20 day high 184.27
# 2018-05-23, Sanity Check, 10 day high 184.27
# 2018-05-24, Sanity Check, 20 day high 184.27
# 2018-05-24, Sanity Check, 10 day high 184.27
# 2018-05-25, Sanity Check, 20 day high 184.27
# 2018-05-25, Sanity Check, 10 day high 183.57
# 2018-05-29, Sanity Check, 20 day high 184.27
# 2018-05-29, Sanity Check, 10 day high 183.56
# 2018-05-30, Sanity Check, 20 day high 184.27
# 2018-05-30, Sanity Check, 10 day high 183.56
# 2018-05-31, Sanity Check, 20 day high 184.27
# 2018-05-31, Sanity Check, 10 day high 183.56
# 2018-06-01, Sanity Check, 20 day high 184.27
# 2018-06-01, Sanity Check, 10 day high 183.56
# 2018-06-04, Sanity Check, 20 day high 185.18
# 2018-06-04, Sanity Check, 10 day high 185.18
# 2018-06-04, BUY CREATE PYRAMID, current open price: 186.54
# 2018-06-04, N value: 3.00
# 2018-06-04, Pyramid: 1.00
# 2018-06-04, N buy in price: 185.95
# 2018-06-04, New previousOrder, should be same as BUY EXECUTED: 184.45
# 2018-06-05, BUY EXECUTED, Price: 187.93, Cost: 1879.30, Comm 1.88
# 2018-06-05, Sanity Check, 20 day high 186.73
# 2018-06-05, Sanity Check, 10 day high 186.73
# 2018-06-06, Sanity Check, 20 day high 188.17
# 2018-06-06, Sanity Check, 10 day high 188.17
# 2018-06-07, Sanity Check, 20 day high 188.82
# 2018-06-07, Sanity Check, 10 day high 188.82
# 2018-06-08, Sanity Check, 20 day high 188.82
# 2018-06-08, Sanity Check, 10 day high 188.82
# 2018-06-11, Sanity Check, 20 day high 188.82
# 2018-06-11, Sanity Check, 10 day high 188.82
# 2018-06-12, Sanity Check, 20 day high 188.82
# 2018-06-12, Sanity Check, 10 day high 188.82
# 2018-06-13, Sanity Check, 20 day high 188.82
# 2018-06-13, Sanity Check, 10 day high 188.82
# 2018-06-14, Sanity Check, 20 day high 188.82
# 2018-06-14, Sanity Check, 10 day high 188.82
# 2018-06-15, Sanity Check, 20 day high 188.82
# 2018-06-15, Sanity Check, 10 day high 188.82
# 2018-06-15, SELL CREATE, 10 day low: 185.18
# 2018-06-15, exit low: 184.97
# 2018-06-18, SELL EXECUTED, Price: 182.88, Cost: 5517.60, Comm 5.49
# 2018-06-18, |||||||||||||||||OPERATION PROFIT, GROSS -31.20, NET -42.20
# 2018-06-18, Sanity Check, 20 day high 188.82
# 2018-06-18, Sanity Check, 10 day high 188.82
# 2018-06-19, Sanity Check, 20 day high 188.82
# 2018-06-19, Sanity Check, 10 day high 188.82
# 2018-06-19, SELL CREATE, 180.21
# 2018-06-20, SELL EXECUTED, Price: 181.39, Cost: -1813.90, Comm 1.81
# 2018-06-20, Sanity Check, 20 day high 188.82
# 2018-06-20, Sanity Check, 10 day high 188.82
# 2018-06-20, SELL CREATE PYRAMID, current open price: 181.39
# 2018-06-20, N value: 2.75
# 2018-06-20, Pyramid: 0.00
# 2018-06-20, N buy in price: 186.55
# 2018-06-20, New previousOrder, should be same as SELL EXECUTED: 187.93
# 2018-06-21, SELL EXECUTED, Price: 182.27, Cost: -1822.70, Comm 1.82
# 2018-06-21, Sanity Check, 20 day high 188.82
# 2018-06-21, Sanity Check, 10 day high 188.31
# 2018-06-21, SELL CREATE PYRAMID, current open price: 182.27
# 2018-06-21, N value: 2.69
# 2018-06-21, Pyramid: 1.00
# 2018-06-21, N buy in price: 186.58
# 2018-06-21, New previousOrder, should be same as SELL EXECUTED: 187.93
# 2018-06-22, SELL EXECUTED, Price: 181.17, Cost: -1811.70, Comm 1.81
# 2018-06-22, Sanity Check, 20 day high 188.82
# 2018-06-22, Sanity Check, 10 day high 187.16
# 2018-06-22, SELL CREATE PYRAMID, current open price: 181.17
# 2018-06-22, N value: 2.72
# 2018-06-22, Pyramid: 2.00
# 2018-06-22, N buy in price: 186.57
# 2018-06-22, New previousOrder, should be same as SELL EXECUTED: 187.93
# 2018-06-25, SELL EXECUTED, Price: 178.52, Cost: -1785.20, Comm 1.79
# 2018-06-25, Sanity Check, 20 day high 188.82
# 2018-06-25, Sanity Check, 10 day high 187.16
# 2018-06-25, SELL CREATE PYRAMID, current open price: 178.52
# 2018-06-25, N value: 2.66
# 2018-06-25, Pyramid: 3.00
# 2018-06-25, N buy in price: 186.60
# 2018-06-25, New previousOrder, should be same as SELL EXECUTED: 187.93
# 2018-06-26, SELL EXECUTED, Price: 178.12, Cost: -1781.20, Comm 1.78
# 2018-06-26, Sanity Check, 20 day high 188.82
# 2018-06-26, Sanity Check, 10 day high 187.16
# 2018-06-26, SELL CREATE PYRAMID, current open price: 178.12
# 2018-06-26, N value: 2.73
# 2018-06-26, Pyramid: 4.00
# 2018-06-26, N buy in price: 186.57
# 2018-06-26, New previousOrder, should be same as SELL EXECUTED: 187.93
# 2018-06-27, SELL EXECUTED, Price: 180.30, Cost: -1803.00, Comm 1.80
# 2018-06-27, Sanity Check, 20 day high 188.82
# 2018-06-27, Sanity Check, 10 day high 185.72
# 2018-06-28, Sanity Check, 20 day high 188.82
# 2018-06-28, Sanity Check, 10 day high 185.72
# 2018-06-29, Sanity Check, 20 day high 188.82
# 2018-06-29, Sanity Check, 10 day high 183.81
# 2018-07-02, Sanity Check, 20 day high 188.82
# 2018-07-02, Sanity Check, 10 day high 183.72
# 2018-07-03, Sanity Check, 20 day high 188.82
# 2018-07-03, Sanity Check, 10 day high 182.20
# 2018-07-03, BUY CREATE, 10 day high: 182.20
# 2018-07-03, exit low: 182.79
# 2018-07-05, BUY EXECUTED, Price: 180.33, Cost: -10817.70, Comm 10.82
# 2018-07-05, |||||||||||||||||OPERATION PROFIT, GROSS -2.10, NET -23.74
# 2018-07-05, Sanity Check, 20 day high 188.82
# 2018-07-05, Sanity Check, 10 day high 182.20
# 2018-07-06, Sanity Check, 20 day high 188.31
# 2018-07-06, Sanity Check, 10 day high 182.20
# 2018-07-09, Sanity Check, 20 day high 187.16
# 2018-07-09, Sanity Check, 10 day high 182.97
# 2018-07-10, Sanity Check, 20 day high 187.16
# 2018-07-10, Sanity Check, 10 day high 185.51
# 2018-07-11, Sanity Check, 20 day high 187.16
# 2018-07-11, Sanity Check, 10 day high 185.51
# 2018-07-12, Sanity Check, 20 day high 185.72
# 2018-07-12, Sanity Check, 10 day high 185.51
# 2018-07-13, Sanity Check, 20 day high 185.95
# 2018-07-13, Sanity Check, 10 day high 185.95
# 2018-07-13, BUY CREATE, 186.00
# 2018-07-13, entry high: 185.95
# 2018-07-16, BUY EXECUTED, Price: 186.42, Cost: 1864.20, Comm 1.86
# 2018-07-16, Sanity Check, 20 day high 186.24
# 2018-07-16, Sanity Check, 10 day high 186.24
# 2018-07-17, Sanity Check, 20 day high 186.24
# 2018-07-17, Sanity Check, 10 day high 186.24
# 2018-07-18, Sanity Check, 20 day high 186.36
# 2018-07-18, Sanity Check, 10 day high 186.36
# 2018-07-19, Sanity Check, 20 day high 186.36
# 2018-07-19, Sanity Check, 10 day high 186.36
# 2018-07-20, Sanity Check, 20 day high 186.77
# 2018-07-20, Sanity Check, 10 day high 186.77
# 2018-07-23, Sanity Check, 20 day high 186.77
# 2018-07-23, Sanity Check, 10 day high 186.77
# 2018-07-24, Sanity Check, 20 day high 186.77
# 2018-07-24, Sanity Check, 10 day high 186.77
# 2018-07-25, Sanity Check, 20 day high 187.86
# 2018-07-25, Sanity Check, 10 day high 187.86
# 2018-07-25, BUY CREATE PYRAMID, current open price: 187.92
# 2018-07-25, N value: 2.62
# 2018-07-25, Pyramid: 0.00
# 2018-07-25, N buy in price: 187.73
# 2018-07-25, New previousOrder, should be same as BUY EXECUTED: 186.42
# 2018-07-26, BUY EXECUTED, Price: 189.43, Cost: 1894.30, Comm 1.89
# 2018-07-26, Sanity Check, 20 day high 189.64
# 2018-07-26, Sanity Check, 10 day high 189.64
# 2018-07-27, Sanity Check, 20 day high 189.64
# 2018-07-27, Sanity Check, 10 day high 189.64
# 2018-07-30, Sanity Check, 20 day high 189.64
# 2018-07-30, Sanity Check, 10 day high 189.64
# 2018-07-31, Sanity Check, 20 day high 189.64
# 2018-07-31, Sanity Check, 10 day high 189.64
# 2018-08-01, Sanity Check, 20 day high 189.64
# 2018-08-01, Sanity Check, 10 day high 189.64
# 2018-08-01, BUY CREATE PYRAMID, current open price: 193.83
# 2018-08-01, N value: 2.73
# 2018-08-01, Pyramid: 1.00
# 2018-08-01, N buy in price: 190.79
# 2018-08-01, New previousOrder, should be same as BUY EXECUTED: 189.43
# 2018-08-02, BUY EXECUTED, Price: 195.24, Cost: 1952.40, Comm 1.95
# 2018-08-02, Sanity Check, 20 day high 196.14
# 2018-08-02, Sanity Check, 10 day high 196.14
# 2018-08-03, Sanity Check, 20 day high 201.87
# 2018-08-03, Sanity Check, 10 day high 201.87
# 2018-08-03, BUY CREATE PYRAMID, current open price: 201.52
# 2018-08-03, N value: 3.38
# 2018-08-03, Pyramid: 2.00
# 2018-08-03, N buy in price: 196.93
# 2018-08-03, New previousOrder, should be same as BUY EXECUTED: 195.24
# 2018-08-06, BUY EXECUTED, Price: 202.46, Cost: 2024.60, Comm 2.02
# 2018-08-06, Sanity Check, 20 day high 202.46
# 2018-08-06, Sanity Check, 10 day high 202.46
# 2018-08-07, Sanity Check, 20 day high 203.51
# 2018-08-07, Sanity Check, 10 day high 203.51
# 2018-08-08, Sanity Check, 20 day high 203.51
# 2018-08-08, Sanity Check, 10 day high 203.51
# 2019-01-14, Sanity Check, 10 day high 154.79
# 2019-01-15, Sanity Check, 20 day high 162.78
# 2019-01-15, Sanity Check, 10 day high 154.79
# 2019-01-16, Sanity Check, 20 day high 162.78
# 2019-01-16, Sanity Check, 10 day high 154.79
# 2019-01-17, Sanity Check, 20 day high 162.78
# 2019-01-17, Sanity Check, 10 day high 151.87
# 2019-01-18, Sanity Check, 20 day high 157.71
# 2019-01-18, Sanity Check, 10 day high 152.78
# 2019-01-22, Sanity Check, 20 day high 154.79
# 2019-01-22, Sanity Check, 10 day high 153.72
# 2019-01-23, Sanity Check, 20 day high 154.79
# 2019-01-23, Sanity Check, 10 day high 153.72
# 2019-01-24, Sanity Check, 20 day high 154.79
# 2019-01-24, Sanity Check, 10 day high 153.72
# 2019-01-25, Sanity Check, 20 day high 154.79
# 2019-01-25, Sanity Check, 10 day high 153.72
# 2019-01-28, Sanity Check, 20 day high 154.79
# 2019-01-28, Sanity Check, 10 day high 154.64
# 2019-01-29, Sanity Check, 20 day high 154.79
# 2019-01-29, Sanity Check, 10 day high 154.64
# 2019-01-30, Sanity Check, 20 day high 154.79
# 2019-01-30, Sanity Check, 10 day high 154.64
# 2019-01-30, tracking:_______SELL TRACK, N stop: 198.95
# 2019-01-30, Current Price: 160.02
# 2019-01-30, N value: 4.77
# 2019-01-31, Sanity Check, 20 day high 161.98
# 2019-01-31, Sanity Check, 10 day high 161.98
# 2019-01-31, BUY CREATE, 162.82
# 2019-01-31, entry high: 161.98
# 2019-02-01, BUY EXECUTED, Price: 163.66, Cost: 1636.60, Comm 1.64
# 2019-02-01, Sanity Check, 20 day high 163.15
# 2019-02-01, Sanity Check, 10 day high 163.15
# 2019-02-04, Sanity Check, 20 day high 163.22
# 2019-02-04, Sanity Check, 10 day high 163.22
# 2019-02-05, Sanity Check, 20 day high 167.86
# 2019-02-05, Sanity Check, 10 day high 167.86
# 2019-02-05, BUY CREATE PYRAMID, current open price: 169.44
# 2019-02-05, N value: 4.96
# 2019-02-05, Pyramid: 0.00
# 2019-02-05, N buy in price: 166.14
# 2019-02-05, New previousOrder, should be same as BUY EXECUTED: 163.66
# 2019-02-06, BUY EXECUTED, Price: 171.19, Cost: 1711.90, Comm 1.71
# 2019-02-06, Sanity Check, 20 day high 170.73
# 2019-02-06, Sanity Check, 10 day high 170.73
# 2019-02-07, Sanity Check, 20 day high 170.79
# 2019-02-07, Sanity Check, 10 day high 170.79
# 2019-02-08, Sanity Check, 20 day high 170.79
# 2019-02-08, Sanity Check, 10 day high 170.79
# 2019-02-11, Sanity Check, 20 day high 170.79
# 2019-02-11, Sanity Check, 10 day high 170.79
# 2019-02-12, Sanity Check, 20 day high 170.79
# 2019-02-12, Sanity Check, 10 day high 170.79
# 2019-02-13, Sanity Check, 20 day high 170.79
# 2019-02-13, Sanity Check, 10 day high 170.79
# 2019-02-14, Sanity Check, 20 day high 170.79
# 2019-02-14, Sanity Check, 10 day high 170.79
# 2019-02-15, Sanity Check, 20 day high 170.79
# 2019-03-22, Sanity Check, 20 day high 192.05
# 2019-03-22, Sanity Check, 10 day high 192.05
# 2019-03-25, Sanity Check, 20 day high 192.05
# 2019-03-25, Sanity Check, 10 day high 192.05
# 2019-03-26, Sanity Check, 20 day high 192.05
# 2019-03-26, Sanity Check, 10 day high 192.05
# 2019-03-27, Sanity Check, 20 day high 192.05
# 2019-03-27, Sanity Check, 10 day high 192.05
# 2019-03-28, Sanity Check, 20 day high 192.05
# 2019-03-28, Sanity Check, 10 day high 192.05
# 2019-03-29, Sanity Check, 20 day high 192.05
# 2019-03-29, Sanity Check, 10 day high 192.05
# 2019-04-01, Sanity Check, 20 day high 192.05
# 2019-04-01, Sanity Check, 10 day high 192.05
# 2019-04-02, Sanity Check, 20 day high 192.05
# 2019-04-02, Sanity Check, 10 day high 192.05
# 2019-04-03, Sanity Check, 20 day high 192.05
# 2019-04-03, Sanity Check, 10 day high 192.05
# 2019-04-04, Sanity Check, 20 day high 192.31
# 2019-04-04, Sanity Check, 10 day high 192.31
# 2019-04-05, Sanity Check, 20 day high 192.64
# 2019-04-05, Sanity Check, 10 day high 192.64
# 2019-04-08, Sanity Check, 20 day high 193.93
# 2019-04-08, Sanity Check, 10 day high 193.93
# 2019-04-09, Sanity Check, 20 day high 196.98
# 2019-04-09, Sanity Check, 10 day high 196.98
# 2019-04-10, Sanity Check, 20 day high 196.98
# 2019-04-10, Sanity Check, 10 day high 196.98
# 2019-04-11, Sanity Check, 20 day high 197.49
# 2019-04-11, Sanity Check, 10 day high 197.49
# 2019-04-12, Sanity Check, 20 day high 197.49
# 2019-04-12, Sanity Check, 10 day high 197.49
# 2019-04-15, Sanity Check, 20 day high 197.49
# 2019-04-15, Sanity Check, 10 day high 197.49
# 2019-04-16, Sanity Check, 20 day high 197.49
# 2019-04-16, Sanity Check, 10 day high 197.49
# 2019-04-17, Sanity Check, 20 day high 197.49
# 2019-04-17, Sanity Check, 10 day high 197.49
# 2019-04-18, Sanity Check, 20 day high 199.96
# 2019-04-18, Sanity Check, 10 day high 199.96
# 2019-04-22, Sanity Check, 20 day high 200.68
# 2019-04-22, Sanity Check, 10 day high 200.68
# 2019-04-23, Sanity Check, 20 day high 201.34
# 2019-04-23, Sanity Check, 10 day high 201.34
# 2019-04-24, Sanity Check, 20 day high 204.25
# 2019-04-24, Sanity Check, 10 day high 204.25
# 2019-04-25, Sanity Check, 20 day high 204.25
# 2019-04-25, Sanity Check, 10 day high 204.25
# 2019-04-26, Sanity Check, 20 day high 204.25
# 2019-04-26, Sanity Check, 10 day high 204.25
# 2019-04-29, Sanity Check, 20 day high 204.25
# 2019-04-29, Sanity Check, 10 day high 204.25
# 2019-04-30, Sanity Check, 20 day high 204.25
# 2019-04-30, Sanity Check, 10 day high 204.25
# 2019-05-01, Sanity Check, 20 day high 204.25
# 2019-05-01, Sanity Check, 10 day high 204.25
# 2019-05-02, Sanity Check, 20 day high 207.24
# 2019-05-02, Sanity Check, 10 day high 207.24
# 2019-05-03, Sanity Check, 20 day high 207.24
# 2019-05-03, Sanity Check, 10 day high 207.24
# 2019-05-06, Sanity Check, 20 day high 208.45
# 2019-05-06, Sanity Check, 10 day high 208.45
# 2019-05-07, Sanity Check, 20 day high 208.45
# 2019-05-07, Sanity Check, 10 day high 208.45
# 2019-05-08, Sanity Check, 20 day high 208.45
# 2019-05-08, Sanity Check, 10 day high 208.45
# 2019-05-09, Sanity Check, 20 day high 208.45
# 2019-05-09, Sanity Check, 10 day high 208.45
# 2019-05-10, Sanity Check, 20 day high 208.45
# 2019-05-10, Sanity Check, 10 day high 208.45
# 2019-05-10, tracking:_______SELL TRACK CREATE, N stop: 181.68
# 2019-05-10, Current Price: 195.09
# 2019-05-10, N value: 4.24
# 2019-05-13, Sanity Check, 20 day high 208.45
# 2019-05-13, Sanity Check, 10 day high 208.45
# 2019-05-13, SELL CREATE, 185.50
# 2019-05-14, SELL EXECUTED, Price: 184.21, Cost: -1842.10, Comm 1.84
# 2019-05-14, Sanity Check, 20 day high 208.45
# 2019-05-14, Sanity Check, 10 day high 208.45
# 2019-05-14, ___________BUY CREATE, N stop: 182.94
# 2019-05-14, Current Price: 184.21
# 2019-05-14, N value: 4.87
# 2019-05-15, BUY EXECUTED, Price: 184.07, Cost: -1842.10, Comm 1.84
# 2019-05-15, |||||||||||||||||OPERATION PROFIT, GROSS 1.40, NET -2.28
# 2019-05-15, Sanity Check, 20 day high 208.45
# 2019-05-15, Sanity Check, 10 day high 208.45
# 2019-05-16, Sanity Check, 20 day high 208.45
# 2019-05-16, Sanity Check, 10 day high 208.45
# 2019-05-17, Sanity Check, 20 day high 208.45
# 2019-05-17, Sanity Check, 10 day high 208.45
# 2019-05-20, Sanity Check, 20 day high 208.45
# 2019-05-20, Sanity Check, 10 day high 205.23
# 2019-05-21, Sanity Check, 20 day high 208.45
# 2019-05-21, Sanity Check, 10 day high 199.74
# 2019-05-22, Sanity Check, 20 day high 208.45
# 2019-05-22, Sanity Check, 10 day high 199.74
# 2019-05-23, Sanity Check, 20 day high 208.45
# 2019-05-23, Sanity Check, 10 day high 197.59
# 2019-05-24, Sanity Check, 20 day high 208.45
# 2019-05-24, Sanity Check, 10 day high 194.85
# 2019-05-28, Sanity Check, 20 day high 208.45
# 2019-05-28, Sanity Check, 10 day high 188.67
# 2019-05-29, Sanity Check, 20 day high 208.45
# 2019-05-29, Sanity Check, 10 day high 188.67
# 2019-05-30, Sanity Check, 20 day high 208.45
# 2019-05-30, Sanity Check, 10 day high 188.67
# 2019-05-31, Sanity Check, 20 day high 208.45
# 2019-05-31, Sanity Check, 10 day high 187.84
# 2019-06-03, Sanity Check, 20 day high 208.45
# 2019-06-03, Sanity Check, 10 day high 186.77
# 2019-06-04, Sanity Check, 20 day high 205.23
# 2019-06-04, Sanity Check, 10 day high 184.40
# 2019-06-05, Sanity Check, 20 day high 199.74
# 2019-06-05, Sanity Check, 10 day high 184.40
# 2019-06-06, Sanity Check, 20 day high 199.74
# 2019-06-06, Sanity Check, 10 day high 180.62
# 2019-06-07, Sanity Check, 20 day high 197.59
# 2019-06-07, Sanity Check, 10 day high 183.04
# 2019-06-10, Sanity Check, 20 day high 194.85
# 2019-06-10, Sanity Check, 10 day high 187.91
# 2019-06-11, Sanity Check, 20 day high 190.31
# 2019-06-11, Sanity Check, 10 day high 190.31
# 2019-06-12, Sanity Check, 20 day high 192.51
# 2019-06-12, Sanity Check, 10 day high 192.51
# 2019-06-13, Sanity Check, 20 day high 192.51
# 2019-06-13, Sanity Check, 10 day high 192.51
# 2019-06-14, Sanity Check, 20 day high 192.51
# 2019-06-14, Sanity Check, 10 day high 192.51
# 2019-06-17, Sanity Check, 20 day high 192.51
# 2019-06-17, Sanity Check, 10 day high 192.51
# 2019-06-18, Sanity Check, 20 day high 192.51
# 2019-06-18, Sanity Check, 10 day high 192.51
# 2019-06-19, Sanity Check, 20 day high 196.11
# 2019-06-19, Sanity Check, 10 day high 196.11
# 2019-06-20, Sanity Check, 20 day high 196.11
# 2019-06-20, Sanity Check, 10 day high 196.11
# 2019-06-21, Sanity Check, 20 day high 197.11
# 2019-06-21, Sanity Check, 10 day high 197.11
# 2019-06-24, Sanity Check, 20 day high 197.11
# 2019-06-24, Sanity Check, 10 day high 197.11
# 2019-06-25, Sanity Check, 20 day high 197.11
# 2019-06-25, Sanity Check, 10 day high 197.11
# 2019-06-26, Sanity Check, 20 day high 197.11
# 2019-06-26, Sanity Check, 10 day high 197.11
# 2019-06-27, Sanity Check, 20 day high 197.44
# 2019-06-27, Sanity Check, 10 day high 197.44
# 2019-06-28, Sanity Check, 20 day high 197.44
# 2019-06-28, Sanity Check, 10 day high 197.44
# 2019-07-01, Sanity Check, 20 day high 197.44
# 2019-07-01, Sanity Check, 10 day high 197.44
# 2019-07-02, Sanity Check, 20 day high 199.17
# 2019-07-02, Sanity Check, 10 day high 199.17
# 2019-07-03, Sanity Check, 20 day high 200.34
# 2019-07-03, Sanity Check, 10 day high 200.34
# 2019-07-05, Sanity Check, 20 day high 202.00
# 2019-07-05, Sanity Check, 10 day high 202.00
# 2019-07-08, Sanity Check, 20 day high 202.00
# 2019-07-08, Sanity Check, 10 day high 202.00
# 2019-07-09, Sanity Check, 20 day high 202.00
# 2019-07-09, Sanity Check, 10 day high 202.00
# 2019-07-10, Sanity Check, 20 day high 202.00
# 2019-07-10, Sanity Check, 10 day high 202.00
# 2019-07-11, Sanity Check, 20 day high 202.00
# 2019-07-11, Sanity Check, 10 day high 202.00
# 2019-07-12, Sanity Check, 20 day high 202.00
# 2019-07-12, Sanity Check, 10 day high 202.00
# 2019-07-15, Sanity Check, 20 day high 202.00
# 2019-07-15, Sanity Check, 10 day high 202.00
# 2019-07-16, Sanity Check, 20 day high 202.79
# 2019-07-16, Sanity Check, 10 day high 202.79
# 2019-07-17, Sanity Check, 20 day high 202.79
# 2019-07-17, Sanity Check, 10 day high 202.79
# 2019-07-18, Sanity Check, 20 day high 202.79
# 2019-07-18, Sanity Check, 10 day high 202.79
# 2019-07-19, Sanity Check, 20 day high 203.23
# 2019-07-19, Sanity Check, 10 day high 203.23
# 2019-07-22, Sanity Check, 20 day high 203.23
# 2019-07-22, Sanity Check, 10 day high 203.23
# 2019-07-23, Sanity Check, 20 day high 204.78
# 2019-07-23, Sanity Check, 10 day high 204.78
# 2019-07-24, Sanity Check, 20 day high 206.38
# 2019-07-24, Sanity Check, 10 day high 206.38
# 2019-07-25, Sanity Check, 20 day high 206.38
# 2019-07-25, Sanity Check, 10 day high 206.38
# 2019-07-26, Sanity Check, 20 day high 206.38
# 2019-07-26, Sanity Check, 10 day high 206.38
# 2019-07-29, Sanity Check, 20 day high 206.38
# 2019-07-29, Sanity Check, 10 day high 206.38
# 2019-07-30, Sanity Check, 20 day high 207.21
# 2019-07-30, Sanity Check, 10 day high 207.21
# 2019-07-31, Sanity Check, 20 day high 207.21
# 2019-07-31, Sanity Check, 10 day high 207.21
# 2019-08-01, Sanity Check, 20 day high 210.53
# 2019-08-01, Sanity Check, 10 day high 210.53
# 2019-08-02, Sanity Check, 20 day high 210.53
# 2019-08-02, Sanity Check, 10 day high 210.53
# 2019-08-05, Sanity Check, 20 day high 210.53
# 2019-08-05, Sanity Check, 10 day high 210.53
# 2019-08-05, tracking:_______SELL TRACK CREATE, N stop: 192.44
# 2019-08-05, Current Price: 195.65
# 2019-08-05, N value: 4.19
# 2019-08-06, Sanity Check, 20 day high 210.53
# 2019-08-06, Sanity Check, 10 day high 210.53
# 2019-08-07, Sanity Check, 20 day high 210.53
# 2019-08-07, Sanity Check, 10 day high 210.53
# 2019-08-08, Sanity Check, 20 day high 210.53
# 2019-08-08, Sanity Check, 10 day high 210.53
# 2019-08-09, Sanity Check, 20 day high 210.53
# 2019-08-09, Sanity Check, 10 day high 210.53
# 2019-08-12, Sanity Check, 20 day high 210.53
# 2019-08-12, Sanity Check, 10 day high 210.53
# 2019-08-13, Sanity Check, 20 day high 210.53
# 2019-08-13, Sanity Check, 10 day high 210.53
# 2019-08-14, Sanity Check, 20 day high 210.53
# 2019-08-14, Sanity Check, 10 day high 210.53
# 2019-08-15, Sanity Check, 20 day high 210.53
# 2019-08-15, Sanity Check, 10 day high 207.29
# 2019-08-16, Sanity Check, 20 day high 210.53
# 2019-08-16, Sanity Check, 10 day high 207.29
# 2019-08-19, Sanity Check, 20 day high 210.53
# 2019-08-19, Sanity Check, 10 day high 207.29
# 2019-08-20, Sanity Check, 20 day high 210.53
# 2019-08-20, Sanity Check, 10 day high 208.66
# 2019-08-21, Sanity Check, 20 day high 210.53
# 2019-08-21, Sanity Check, 10 day high 208.67
# 2019-08-21, BUY CREATE, 211.28
# 2019-08-21, entry high: 210.53
# 2019-08-22, BUY EXECUTED, Price: 211.48, Cost: 2114.80, Comm 2.11
# 2019-08-22, Sanity Check, 20 day high 210.93
# 2019-08-22, Sanity Check, 10 day high 210.93
# 2019-08-23, Sanity Check, 20 day high 210.93
# 2019-08-23, Sanity Check, 10 day high 210.93
# 2019-08-26, Sanity Check, 20 day high 210.93
# 2019-08-26, Sanity Check, 10 day high 210.93
# 2019-08-27, Sanity Check, 20 day high 210.93
# 2019-08-27, Sanity Check, 10 day high 210.93
# 2019-08-28, Sanity Check, 20 day high 210.93
# 2019-08-28, Sanity Check, 10 day high 210.93
# 2019-08-29, Sanity Check, 20 day high 210.93
# 2019-08-29, Sanity Check, 10 day high 210.93
# 2019-08-30, Sanity Check, 20 day high 210.93
# 2019-08-30, Sanity Check, 10 day high 210.93
# 2019-09-03, Sanity Check, 20 day high 210.93
# 2019-09-03, Sanity Check, 10 day high 210.93
# 2019-09-04, Sanity Check, 20 day high 210.93
# 2019-09-04, Sanity Check, 10 day high 210.93
# 2019-09-05, Sanity Check, 20 day high 210.93
# 2019-09-05, Sanity Check, 10 day high 210.93
# 2019-09-06, Sanity Check, 20 day high 211.57
# 2019-09-06, Sanity Check, 10 day high 211.57
# 2019-09-09, Sanity Check, 20 day high 211.57
# 2019-09-09, Sanity Check, 10 day high 211.57
# 2019-09-10, Sanity Check, 20 day high 212.45
# 2019-09-10, Sanity Check, 10 day high 212.45
# 2019-09-11, Sanity Check, 20 day high 214.96
# 2019-09-11, Sanity Check, 10 day high 214.96
# 2019-09-11, BUY CREATE PYRAMID, current open price: 216.32
# 2019-09-11, N value: 4.64
# 2019-09-11, Pyramid: 0.00
# 2019-09-11, N buy in price: 213.80
# 2019-09-11, New previousOrder, should be same as BUY EXECUTED: 211.48
# 2019-09-12, BUY EXECUTED, Price: 222.99, Cost: 2229.90, Comm 2.23
# 2019-09-12, Sanity Check, 20 day high 221.79
# 2019-09-12, Sanity Check, 10 day high 221.79
# 2019-09-13, Sanity Check, 20 day high 221.79
# 2019-09-13, Sanity Check, 10 day high 221.79
# 2019-09-16, Sanity Check, 20 day high 221.79
# 2019-09-16, Sanity Check, 10 day high 221.79
# 2019-09-17, Sanity Check, 20 day high 221.79
# 2019-09-17, Sanity Check, 10 day high 221.79
# 2019-09-18, Sanity Check, 20 day high 221.79
# 2019-09-18, Sanity Check, 10 day high 221.79
# 2019-09-19, Sanity Check, 20 day high 221.79
# 2019-09-19, Sanity Check, 10 day high 221.79
# 2019-09-20, Sanity Check, 20 day high 221.79
# 2019-09-20, Sanity Check, 10 day high 221.79
# 2019-09-23, Sanity Check, 20 day high 221.79
# 2019-09-23, Sanity Check, 10 day high 221.79
# 2019-09-24, Sanity Check, 20 day high 221.79
# 2019-09-24, Sanity Check, 10 day high 221.79
# 2019-09-25, Sanity Check, 20 day high 221.79
# 2019-09-25, Sanity Check, 10 day high 221.79
# 2019-09-26, Sanity Check, 20 day high 221.79
# 2019-09-26, Sanity Check, 10 day high 221.30
# 2019-09-27, Sanity Check, 20 day high 221.79
# 2019-09-27, Sanity Check, 10 day high 220.98
# 2019-09-30, Sanity Check, 20 day high 221.79
# 2019-09-30, Sanity Check, 10 day high 220.98
# 2019-10-01, Sanity Check, 20 day high 222.17
# 2019-10-01, Sanity Check, 10 day high 222.17
# 2019-10-02, Sanity Check, 20 day high 222.78
# 2019-10-02, Sanity Check, 10 day high 222.78
# 2019-10-03, Sanity Check, 20 day high 222.78
# 2019-10-03, Sanity Check, 10 day high 222.78
# 2019-10-04, Sanity Check, 20 day high 222.78
# 2019-10-04, Sanity Check, 10 day high 222.78
# 2019-10-07, Sanity Check, 20 day high 225.19
# 2019-10-07, Sanity Check, 10 day high 225.19
# 2019-10-08, Sanity Check, 20 day high 225.23
# 2019-10-08, Sanity Check, 10 day high 225.23
# 2019-10-09, Sanity Check, 20 day high 225.23
# 2019-10-09, Sanity Check, 10 day high 225.23
# 2019-10-10, Sanity Check, 20 day high 225.23
# 2019-10-10, Sanity Check, 10 day high 225.23
# 2019-10-10, BUY CREATE PYRAMID, current open price: 226.10
# 2019-10-10, N value: 4.45
# 2019-10-10, Pyramid: 1.00
# 2019-10-10, N buy in price: 225.22
# 2019-10-10, New previousOrder, should be same as BUY EXECUTED: 222.99
# 2019-10-11, BUY EXECUTED, Price: 231.08, Cost: 2310.80, Comm 2.31
# 2019-10-11, Sanity Check, 20 day high 228.24
# 2019-10-11, Sanity Check, 10 day high 228.24
# 2019-10-14, Sanity Check, 20 day high 234.31
# 2019-10-14, Sanity Check, 10 day high 234.31
# 2019-10-15, Sanity Check, 20 day high 234.31
# 2019-10-15, Sanity Check, 10 day high 234.31
# 2019-10-15, BUY CREATE PYRAMID, current open price: 234.49
# 2019-10-15, N value: 4.50
# 2019-10-15, Pyramid: 2.00
# 2019-10-15, N buy in price: 233.33
# 2019-10-15, New previousOrder, should be same as BUY EXECUTED: 231.08
# 2019-10-16, BUY EXECUTED, Price: 231.49, Cost: 2314.90, Comm 2.31
# 2019-10-16, Sanity Check, 20 day high 234.31
# 2019-10-16, Sanity Check, 10 day high 234.31
# 2019-10-17, Sanity Check, 20 day high 234.31
# 2019-10-17, Sanity Check, 10 day high 234.31
# 2019-10-18, Sanity Check, 20 day high 234.31
# 2019-10-18, Sanity Check, 10 day high 234.31
# 2019-10-21, Sanity Check, 20 day high 234.51
# 2019-10-21, Sanity Check, 10 day high 234.51
# 2019-10-21, BUY CREATE PYRAMID, current open price: 235.61
# 2019-10-21, N value: 4.16
# 2019-10-21, Pyramid: 3.00
# 2019-10-21, N buy in price: 233.57
# 2019-10-21, New previousOrder, should be same as BUY EXECUTED: 231.49
# 2019-10-22, BUY EXECUTED, Price: 239.22, Cost: 2392.20, Comm 2.39
# 2019-10-22, Sanity Check, 20 day high 238.58
# 2019-10-22, Sanity Check, 10 day high 238.58
# 2019-10-23, Sanity Check, 20 day high 238.58
# 2019-10-23, Sanity Check, 10 day high 238.58
# 2019-10-24, Sanity Check, 20 day high 241.23
# 2019-10-24, Sanity Check, 10 day high 241.23
# 2019-10-24, BUY CREATE PYRAMID, current open price: 242.54
# 2019-10-24, N value: 4.06
# 2019-10-24, Pyramid: 4.00
# 2019-10-24, N buy in price: 241.25
# 2019-10-24, New previousOrder, should be same as BUY EXECUTED: 239.22
