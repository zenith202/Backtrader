# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# Create a Stratey
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 15),
    )

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add a MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

        # Indicators for the plotting show
        bt.indicators.ExponentialMovingAverage(self.datas[0], period=25)
        #bt.indicators.WeightedMovingAverage(self.datas[0], period=25,subplot=True)
        #bt.indicators.StochasticSlow(self.datas[0])
        #bt.indicators.MACDHisto(self.datas[0])
        rsi = bt.indicators.RSI(self.datas[0])
        #bt.indicators.SmoothedMovingAverage(rsi, period=10)
        self.atr = bt.indicators.ATR(self.datas[0])

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            #if self.dataclose[0] > self.sma[0]:
            if self.atr[0] > self.atr[-1]:

                # BUY, BUY, BUY!!! (with all possible default parameters)
                #self.log('BUY CREATE, %.2f' % self.dataclose[0])
                self.log('BUY CREATE ATR, %.2f' % self.atr[0])
                self.log('Previous ATR: %.2f' % self.atr[-1])
                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()

        else:

            if self.dataclose[0] < self.sma[0]:
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()


if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)

    # Datas are in a subfolder of the samples. Need to find where the script is
    # because it could have been called from anywhere
    #modpath = os.path.dirname(os.path.abspath(sys.argv[0]))
    #datapath = os.path.join(modpath, '../../datas/orcl-1995-2014.txt')

    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname='/Users/Ziyi/Desktop/AAPL.csv', 
        fromdate=datetime.datetime(2019, 1, 1), 
        todate=datetime.datetime(2019, 12, 31),
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(1000.0)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission
    cerebro.broker.setcommission(commission=0.001)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Plot the result
    cerebro.plot()
# Out:
# Starting Portfolio Value: 1000.00
# 2019-02-06, Close, 171.66
# 2019-02-07, Close, 168.41
# 2019-02-08, Close, 168.61
# 2019-02-11, Close, 167.64
# 2019-02-12, Close, 169.08
# 2019-02-13, Close, 168.38
# 2019-02-14, Close, 168.99
# 2019-02-15, Close, 168.62
# 2019-02-19, Close, 169.12
# 2019-02-20, Close, 170.21
# 2019-02-21, Close, 169.25
# 2019-02-22, Close, 171.14
# 2019-02-25, Close, 172.39
# 2019-02-26, Close, 172.49
# 2019-02-27, Close, 173.02
# 2019-02-28, Close, 171.32
# 2019-03-01, Close, 173.12
# 2019-03-04, Close, 173.99
# 2019-03-04, BUY CREATE ATR, 2.96
# 2019-03-04, Previous ATR: 2.90
# 2019-03-05, Order Canceled/Margin/Rejected
# 2019-03-05, Close, 173.67
# 2019-03-06, Close, 172.67
# 2019-03-07, Close, 170.68
# 2019-03-08, Close, 171.08
# 2019-03-08, BUY CREATE ATR, 2.79
# 2019-03-08, Previous ATR: 2.74
# 2019-03-11, Order Canceled/Margin/Rejected
# 2019-03-11, Close, 177.01
# 2019-03-11, BUY CREATE ATR, 3.03
# 2019-03-11, Previous ATR: 2.79
# 2019-03-12, Order Canceled/Margin/Rejected
# 2019-03-12, Close, 179.00
# 2019-03-12, BUY CREATE ATR, 3.08
# 2019-03-12, Previous ATR: 3.03
# 2019-03-13, Order Canceled/Margin/Rejected
# 2019-03-13, Close, 179.79
# 2019-03-14, Close, 181.79
# 2019-03-15, Close, 184.15
# 2019-03-15, BUY CREATE ATR, 3.02
# 2019-03-15, Previous ATR: 2.98
# 2019-03-18, Order Canceled/Margin/Rejected
# 2019-03-18, Close, 186.03
# 2019-03-19, Close, 184.56
# 2019-03-19, BUY CREATE ATR, 3.00
# 2019-03-19, Previous ATR: 2.99
# 2019-03-20, Order Canceled/Margin/Rejected
# 2019-03-20, Close, 186.17
# 2019-03-20, BUY CREATE ATR, 3.12
# 2019-03-20, Previous ATR: 3.00
# 2019-03-21, Order Canceled/Margin/Rejected
# 2019-03-21, Close, 193.03
# 2019-03-21, BUY CREATE ATR, 3.47
# 2019-03-21, Previous ATR: 3.12
# 2019-03-22, Order Canceled/Margin/Rejected
# 2019-03-22, Close, 189.03
# 2019-03-22, BUY CREATE ATR, 3.71
# 2019-03-22, Previous ATR: 3.47
# 2019-03-25, Order Canceled/Margin/Rejected
# 2019-03-25, Close, 186.74
# 2019-03-25, BUY CREATE ATR, 3.83
# 2019-03-25, Previous ATR: 3.71
# 2019-03-26, Order Canceled/Margin/Rejected
# 2019-03-26, Close, 184.81
# 2019-03-26, BUY CREATE ATR, 4.14
# 2019-03-26, Previous ATR: 3.83
# 2019-03-27, Order Canceled/Margin/Rejected
# 2019-03-27, Close, 186.48
# 2019-03-28, Close, 186.72
# 2019-03-29, Close, 187.94
# 2019-04-01, Close, 189.22
# 2019-04-02, Close, 191.97
# 2019-04-03, Close, 193.28
# 2019-04-04, Close, 193.62
# 2019-04-05, Close, 194.92
# 2019-04-08, Close, 197.98
# 2019-04-08, BUY CREATE ATR, 3.50
# 2019-04-08, Previous ATR: 3.47
# 2019-04-09, Order Canceled/Margin/Rejected
# 2019-04-09, Close, 197.39
# 2019-04-09, BUY CREATE ATR, 3.50
# 2019-04-09, Previous ATR: 3.50
# 2019-04-10, Order Canceled/Margin/Rejected
# 2019-04-10, Close, 198.50
# 2019-04-11, Close, 196.85
# 2019-04-12, Close, 196.77
# 2019-04-12, BUY CREATE ATR, 3.41
# 2019-04-12, Previous ATR: 3.37
# 2019-04-15, Order Canceled/Margin/Rejected
# 2019-04-15, Close, 197.12
# 2019-04-16, Close, 197.14
# 2019-04-17, Close, 200.98
# 2019-04-17, BUY CREATE ATR, 3.36
# 2019-04-17, Previous ATR: 3.26
# 2019-04-18, Order Canceled/Margin/Rejected
# 2019-04-18, Close, 201.70
# 2019-04-22, Close, 202.37
# 2019-04-23, Close, 205.29
# 2019-04-23, BUY CREATE ATR, 3.23
# 2019-04-23, Previous ATR: 3.19
# 2019-04-24, Order Canceled/Margin/Rejected
# 2019-04-24, Close, 204.97
# 2019-04-25, Close, 203.11
# 2019-04-26, Close, 202.14
# 2019-04-26, BUY CREATE ATR, 3.07
# 2019-04-26, Previous ATR: 3.07
# 2019-04-29, Order Canceled/Margin/Rejected
# 2019-04-29, Close, 202.45
# 2019-04-30, Close, 198.55
# 2019-04-30, BUY CREATE ATR, 3.18
# 2019-04-30, Previous ATR: 3.00
# 2019-05-01, Order Canceled/Margin/Rejected
# 2019-05-01, Close, 208.29
# 2019-05-01, BUY CREATE ATR, 3.98
# 2019-05-01, Previous ATR: 3.18
# 2019-05-02, Order Canceled/Margin/Rejected
# 2019-05-02, Close, 206.94
# 2019-05-02, BUY CREATE ATR, 4.02
# 2019-05-02, Previous ATR: 3.98
# 2019-05-03, Order Canceled/Margin/Rejected
# 2019-05-03, Close, 209.51
# 2019-05-06, Close, 206.27
# 2019-05-06, BUY CREATE ATR, 4.22
# 2019-05-06, Previous ATR: 3.92
# 2019-05-07, Order Canceled/Margin/Rejected
# 2019-05-07, Close, 200.71
# 2019-05-07, BUY CREATE ATR, 4.46
# 2019-05-07, Previous ATR: 4.22
# 2019-05-08, Order Canceled/Margin/Rejected
# 2019-05-08, Close, 200.75
# 2019-05-09, Close, 198.60
# 2019-05-09, BUY CREATE ATR, 4.52
# 2019-05-09, Previous ATR: 4.40
# 2019-05-10, Order Canceled/Margin/Rejected
# 2019-05-10, Close, 195.85
# 2019-05-10, BUY CREATE ATR, 4.71
# 2019-05-10, Previous ATR: 4.52
# 2019-05-13, Order Canceled/Margin/Rejected
# 2019-05-13, Close, 184.46
# 2019-05-13, BUY CREATE ATR, 5.39
# 2019-05-13, Previous ATR: 4.71
# 2019-05-14, Order Canceled/Margin/Rejected
# 2019-05-14, Close, 187.38
# 2019-05-15, Close, 189.63
# 2019-05-15, BUY CREATE ATR, 5.34
# 2019-05-15, Previous ATR: 5.31
# 2019-05-16, Order Canceled/Margin/Rejected
# 2019-05-16, Close, 188.79
# 2019-05-17, Close, 187.72
# 2019-05-20, Close, 181.85
# 2019-05-20, BUY CREATE ATR, 5.39
# 2019-05-20, Previous ATR: 5.14
# 2019-05-21, Order Canceled/Margin/Rejected
# 2019-05-21, Close, 185.34
# 2019-05-22, Close, 181.54
# 2019-05-23, Close, 178.44
# 2019-05-24, Close, 177.76
# 2019-05-28, Close, 177.02
# 2019-05-29, Close, 176.18
# 2019-05-30, Close, 177.09
# 2019-05-31, Close, 173.89
# 2019-06-03, Close, 172.13
# 2019-06-03, BUY CREATE ATR, 4.78
# 2019-06-03, Previous ATR: 4.56
# 2019-06-04, Order Canceled/Margin/Rejected
# 2019-06-04, Close, 178.42
# 2019-06-04, BUY CREATE ATR, 4.90
# 2019-06-04, Previous ATR: 4.78
# 2019-06-05, Order Canceled/Margin/Rejected
# 2019-06-05, Close, 181.30
# 2019-06-05, BUY CREATE ATR, 4.93
# 2019-06-05, Previous ATR: 4.90
# 2019-06-06, Order Canceled/Margin/Rejected
# 2019-06-06, Close, 183.97
# 2019-06-07, Close, 188.86
# 2019-06-07, BUY CREATE ATR, 4.94
# 2019-06-07, Previous ATR: 4.81
# 2019-06-10, Order Canceled/Margin/Rejected
# 2019-06-10, Close, 191.28
# 2019-06-10, BUY CREATE ATR, 4.96
# 2019-06-10, Previous ATR: 4.94
# 2019-06-11, Order Canceled/Margin/Rejected
# 2019-06-11, Close, 193.49
# 2019-06-12, Close, 192.88
# 2019-06-13, Close, 192.84
# 2019-06-14, Close, 191.44
# 2019-06-17, Close, 192.58
# 2019-06-18, Close, 197.11
# 2019-06-18, BUY CREATE ATR, 4.54
# 2019-06-18, Previous ATR: 4.40
# 2019-06-19, Order Canceled/Margin/Rejected
# 2019-06-19, Close, 196.53
# 2019-06-20, Close, 198.11
# 2019-06-21, Close, 197.43
# 2019-06-24, Close, 197.24
# 2019-06-25, Close, 194.25
# 2019-06-26, Close, 198.45
# 2019-06-26, BUY CREATE ATR, 4.10
# 2019-06-26, Previous ATR: 4.00
# 2019-06-27, Order Canceled/Margin/Rejected
# 2019-06-27, Close, 198.39
# 2019-06-28, Close, 196.58
# 2019-07-01, Close, 200.19
# 2019-07-01, BUY CREATE ATR, 4.05
# 2019-07-01, Previous ATR: 3.86
# 2019-07-02, Order Canceled/Margin/Rejected
# 2019-07-02, Close, 201.36
# 2019-07-03, Close, 203.03
# 2019-07-05, Close, 202.85
# 2019-07-08, Close, 198.67
# 2019-07-08, BUY CREATE ATR, 3.77
# 2019-07-08, Previous ATR: 3.62
# 2019-07-09, Order Canceled/Margin/Rejected
# 2019-07-09, Close, 199.88
# 2019-07-10, Close, 201.85
# 2019-07-11, Close, 200.38
# 2019-07-12, Close, 201.92
# 2019-07-15, Close, 203.82
# 2019-07-16, Close, 203.12
# 2019-07-17, Close, 201.97
# 2019-07-18, Close, 204.27
# 2019-07-19, Close, 201.22
# 2019-07-19, BUY CREATE ATR, 3.24
# 2019-07-19, Previous ATR: 3.17
# 2019-07-22, Order Canceled/Margin/Rejected
# 2019-07-22, Close, 205.82
# 2019-07-22, BUY CREATE ATR, 3.34
# 2019-07-22, Previous ATR: 3.24
# 2019-07-23, Order Canceled/Margin/Rejected
# 2019-07-23, Close, 207.43
# 2019-07-24, Close, 207.26
# 2019-07-25, Close, 205.62
# 2019-07-26, Close, 206.33
# 2019-07-29, Close, 208.26
# 2019-07-30, Close, 207.37
# 2019-07-31, Close, 211.60
# 2019-07-31, BUY CREATE ATR, 3.70
# 2019-07-31, Previous ATR: 3.03
# 2019-08-01, Order Canceled/Margin/Rejected
# 2019-08-01, Close, 207.02
# 2019-08-01, BUY CREATE ATR, 4.24
# 2019-08-01, Previous ATR: 3.70
# 2019-08-02, Order Canceled/Margin/Rejected
# 2019-08-02, Close, 202.64
# 2019-08-02, BUY CREATE ATR, 4.42
# 2019-08-02, Previous ATR: 4.24
# 2019-08-05, Order Canceled/Margin/Rejected
# 2019-08-05, Close, 192.03
# 2019-08-05, BUY CREATE ATR, 4.91
# 2019-08-05, Previous ATR: 4.42
# 2019-08-06, Order Canceled/Margin/Rejected
# 2019-08-06, Close, 195.67
# 2019-08-07, Close, 197.69
# 2019-08-07, BUY CREATE ATR, 4.96
# 2019-08-07, Previous ATR: 4.90
# 2019-08-08, Order Canceled/Margin/Rejected
# 2019-08-08, Close, 202.05
# 2019-08-09, Close, 200.39
# 2019-08-12, Close, 199.88
# 2019-08-13, Close, 208.34
# 2019-08-13, BUY CREATE ATR, 5.18
# 2019-08-13, Previous ATR: 4.68
# 2019-08-14, Order Canceled/Margin/Rejected
# 2019-08-14, Close, 202.14
# 2019-08-14, BUY CREATE ATR, 5.26
# 2019-08-14, Previous ATR: 5.18
# 2019-08-15, Order Canceled/Margin/Rejected
# 2019-08-15, Close, 201.14
# 2019-08-15, BUY CREATE ATR, 5.27
# 2019-08-15, Previous ATR: 5.26
# 2019-08-16, Order Canceled/Margin/Rejected
# 2019-08-16, Close, 205.88
# 2019-08-16, BUY CREATE ATR, 5.28
# 2019-08-16, Previous ATR: 5.27
# 2019-08-19, Order Canceled/Margin/Rejected
# 2019-08-19, Close, 209.72
# 2019-08-19, BUY CREATE ATR, 5.35
# 2019-08-19, Previous ATR: 5.28
# 2019-08-20, Order Canceled/Margin/Rejected
# 2019-08-20, Close, 209.73
# 2019-08-21, Close, 212.00
# 2019-08-22, Close, 211.82
# 2019-08-23, Close, 202.03
# 2019-08-23, BUY CREATE ATR, 5.41
# 2019-08-23, Previous ATR: 4.95
# 2019-08-26, Order Canceled/Margin/Rejected
# 2019-08-26, Close, 205.87
# 2019-08-27, Close, 203.55
# 2019-08-28, Close, 204.91
# 2019-08-29, Close, 208.38
# 2019-08-30, Close, 208.12
# 2019-09-03, Close, 205.08
# 2019-09-04, Close, 208.56
# 2019-09-05, Close, 212.64
# 2019-09-06, Close, 212.62
# 2019-09-09, Close, 213.53
# 2019-09-09, BUY CREATE ATR, 4.64
# 2019-09-09, Previous ATR: 4.58
# 2019-09-10, Order Canceled/Margin/Rejected
# 2019-09-10, Close, 216.05
# 2019-09-10, BUY CREATE ATR, 4.67
# 2019-09-10, Previous ATR: 4.64
# 2019-09-11, Order Canceled/Margin/Rejected
# 2019-09-11, Close, 222.92
# 2019-09-11, BUY CREATE ATR, 4.83
# 2019-09-11, Previous ATR: 4.67
# 2019-09-12, Order Canceled/Margin/Rejected
# 2019-09-12, Close, 222.42
# 2019-09-13, Close, 218.10
# 2019-09-13, BUY CREATE ATR, 4.83
# 2019-09-13, Previous ATR: 4.74
# 2019-09-16, Order Canceled/Margin/Rejected
# 2019-09-16, Close, 219.24
# 2019-09-17, Close, 220.04
# 2019-09-18, Close, 222.10
# 2019-09-19, Close, 220.30
# 2019-09-20, Close, 217.08
# 2019-09-20, BUY CREATE ATR, 4.37
# 2019-09-20, Previous ATR: 4.31
# 2019-09-23, Order Canceled/Margin/Rejected
# 2019-09-23, Close, 218.07
# 2019-09-24, Close, 217.03
# 2019-09-24, BUY CREATE ATR, 4.29
# 2019-09-24, Previous ATR: 4.21
# 2019-09-25, Order Canceled/Margin/Rejected
# 2019-09-25, Close, 220.37
# 2019-09-25, BUY CREATE ATR, 4.29
# 2019-09-25, Previous ATR: 4.29
# 2019-09-26, Order Canceled/Margin/Rejected
# 2019-09-26, Close, 219.23
# 2019-09-27, Close, 218.17
# 2019-09-30, Close, 223.30
# 2019-09-30, BUY CREATE ATR, 4.22
# 2019-09-30, Previous ATR: 4.11
# 2019-10-01, Order Canceled/Margin/Rejected
# 2019-10-01, Close, 223.92
# 2019-10-01, BUY CREATE ATR, 4.23
# 2019-10-01, Previous ATR: 4.22
# 2019-10-02, Order Canceled/Margin/Rejected
# 2019-10-02, Close, 218.30
# 2019-10-02, BUY CREATE ATR, 4.40
# 2019-10-02, Previous ATR: 4.23
# 2019-10-03, Order Canceled/Margin/Rejected
# 2019-10-03, Close, 220.16
# 2019-10-03, BUY CREATE ATR, 4.50
# 2019-10-03, Previous ATR: 4.40
# 2019-10-04, Order Canceled/Margin/Rejected
# 2019-10-04, Close, 226.33
# 2019-10-04, BUY CREATE ATR, 4.65
# 2019-10-04, Previous ATR: 4.50
# 2019-10-07, Order Canceled/Margin/Rejected
# 2019-10-07, Close, 226.38
# 2019-10-08, Close, 223.73
# 2019-10-09, Close, 226.35
# 2019-10-10, Close, 229.40
# 2019-10-11, Close, 235.50
# 2019-10-11, BUY CREATE ATR, 4.61
# 2019-10-11, Previous ATR: 4.39
# 2019-10-14, Order Canceled/Margin/Rejected
# 2019-10-14, Close, 235.16
# 2019-10-15, Close, 234.62
# 2019-10-16, Close, 233.67
# 2019-10-17, Close, 234.58
# 2019-10-18, Close, 235.70
# 2019-10-21, Close, 239.79
# 2019-10-21, BUY CREATE ATR, 4.10
# 2019-10-21, Previous ATR: 4.06
# 2019-10-22, Order Canceled/Margin/Rejected
# 2019-10-22, Close, 239.24
# 2019-10-23, Close, 242.45
# 2019-10-24, Close, 242.85
# 2019-10-25, Close, 245.84
# 2019-10-28, Close, 248.30
# 2019-10-29, Close, 242.56
# 2019-10-29, BUY CREATE ATR, 4.02
# 2019-10-29, Previous ATR: 3.78
# 2019-10-30, Order Canceled/Margin/Rejected
# 2019-10-30, Close, 242.53
# 2019-10-30, BUY CREATE ATR, 4.03
# 2019-10-30, Previous ATR: 4.02
# 2019-10-31, Order Canceled/Margin/Rejected
# 2019-10-31, Close, 248.02
# 2019-10-31, BUY CREATE ATR, 4.59
# 2019-10-31, Previous ATR: 4.03
# 2019-11-01, Order Canceled/Margin/Rejected
# 2019-11-01, Close, 255.05
# 2019-11-01, BUY CREATE ATR, 4.77
# 2019-11-01, Previous ATR: 4.59
# 2019-11-04, Order Canceled/Margin/Rejected
# 2019-11-04, Close, 256.73
# 2019-11-05, Close, 256.36
# 2019-11-06, Close, 256.47
# 2019-11-07, Close, 259.43
# 2019-11-08, Close, 260.14
# 2019-11-11, Close, 262.20
# 2019-11-11, BUY CREATE ATR, 4.18
# 2019-11-11, Previous ATR: 4.17
# 2019-11-12, Order Canceled/Margin/Rejected
# 2019-11-12, Close, 261.96
# 2019-11-13, Close, 264.47
# 2019-11-14, Close, 262.64
# 2019-11-15, Close, 265.76
# 2019-11-18, Close, 267.10
# 2019-11-19, Close, 266.29
# 2019-11-20, Close, 263.19
# 2019-11-20, BUY CREATE ATR, 3.87
# 2019-11-20, Previous ATR: 3.72
# 2019-11-21, Order Canceled/Margin/Rejected
# 2019-11-21, Close, 262.01
# 2019-11-22, Close, 261.78
# 2019-11-25, Close, 266.37
# 2019-11-25, BUY CREATE ATR, 3.76
# 2019-11-25, Previous ATR: 3.69
# 2019-11-26, Order Canceled/Margin/Rejected
# 2019-11-26, Close, 264.29
# 2019-11-26, BUY CREATE ATR, 3.83
# 2019-11-26, Previous ATR: 3.76
# 2019-11-27, Order Canceled/Margin/Rejected
# 2019-11-27, Close, 267.84
# 2019-11-29, Close, 267.25
# 2019-12-02, Close, 264.16
# 2019-12-02, BUY CREATE ATR, 3.77
# 2019-12-02, Previous ATR: 3.69
# 2019-12-03, Order Canceled/Margin/Rejected
# 2019-12-03, Close, 259.45
# 2019-12-03, BUY CREATE ATR, 4.07
# 2019-12-03, Previous ATR: 3.77
# 2019-12-04, Order Canceled/Margin/Rejected
# 2019-12-04, Close, 261.74
# 2019-12-05, Close, 265.58
# 2019-12-05, BUY CREATE ATR, 4.06
# 2019-12-05, Previous ATR: 4.05
# 2019-12-06, Order Canceled/Margin/Rejected
# 2019-12-06, Close, 270.71
# 2019-12-06, BUY CREATE ATR, 4.16
# 2019-12-06, Previous ATR: 4.06
# 2019-12-09, Order Canceled/Margin/Rejected
# 2019-12-09, Close, 266.92
# 2019-12-09, BUY CREATE ATR, 4.28
# 2019-12-09, Previous ATR: 4.16
# 2019-12-10, Order Canceled/Margin/Rejected
# 2019-12-10, Close, 268.48
# Final Portfolio Value: 1000.00

# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt


# Create a Stratey
class TestStrategy(bt.Strategy):

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None
        self.long = None
        self.pyramid = 0
        self.previousOrder = None
        self.totalNumberOfOrders = 0
        self.selling = False
        
        # 20 day ATR for N value
        self.atr = bt.indicators.ATR(self.datas[0], period = 20)
        
        # System 1: 20 day entry, 10 day exit
        self.entry = bt.indicators.Highest(period=20)
        self.exit = bt.indicators.Lowest(period=10)
        
        # System 2: 55 day entry, 20 day exit

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
                self.previousOrder = order.executed.price
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        #self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.entry[-1] < self.dataclose[0]:

                    # BUY, BUY, BUY!!! (with default parameters)
                    self.log('BUY CREATE, %.2f' % self.dataclose[0])
                    self.log('entry high: %.2f' % self.entry[-1])

                    # Keep track of the created order to avoid a 2nd order
                    self.order = self.buy()
                    self.selling = False
                    #self.long = True

        else:
            # in the market, see if we can pyramid our position
            if self.pyramid < 5 and self.dataclose[0] > (self.previousOrder + 1/2*self.atr[-1]) and not self.selling:
                # BUY, BUY, BUY!!! (with default parameters)
                self.log('BUY CREATE PYRAMID, current close price: %.2f' % self.dataclose[0])
                self.log('N value: %.2f' % self.atr[-1])
                self.log('Pyramid: %.2f' % self.pyramid)
                self.log('N buy in price: %.2f' % (self.previousOrder + 1/2*self.atr[-1]))
                
                self.pyramid+=1
                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()
                self.log('New previousOrder, should be same as BUY EXECUTED: %.2f' % self.previousOrder)
                

            # Already in the market ... we might sell
            if self.exit[-1] > self.dataclose[0]:
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, 10 day low: %.2f' % self.exit[-1])
                self.log('exit low: %.2f' % self.dataclose[0])
                # Keep track of the created order to avoid a 2nd order
                self.pyramid = 0
                self.order = self.sell()
                self.selling = True
                
            elif self.dataclose[0] < (self.dataclose[-1]-2*self.atr[-1]):
                stopPrice = self.dataclose[-1]-2*self.atr[-1]
                self.log('SELL CREATE, N stop: %.2f' % stopPrice)
                self.log('Current Price: %.2f' % self.dataclose[0])
                self.log('N value: %.2f' % self.atr[-1])
                # Keep track of the created order to avoid a 2nd order
                self.pyramid = 0
                self.order = self.sell()
                self.selling = True


if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(TestStrategy)


    # Create a Data Feed
    data = bt.feeds.YahooFinanceCSVData(
        dataname='/Users/Ziyi/Downloads/AAPL.csv', 
         fromdate=datetime.datetime(2019, 1, 1), 
         todate=datetime.datetime(2019, 12, 31),
        reverse=False)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(100000.0)
    
    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission - 0.1% ... divide by 100 to remove the %
    cerebro.broker.setcommission(commission=0.001)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2019-01-31, BUY CREATE, 163.98
# 2019-01-31, entry high: 162.80
# 2019-02-01, BUY EXECUTED, Price: 164.49, Cost: 1644.90, Comm 1.64
# 2019-02-04, BUY CREATE PYRAMID, current close price: 168.72
# 2019-02-04, N value: 4.60
# 2019-02-04, Pyramid: 0.00
# 2019-02-04, N buy in price: 166.79
# 2019-02-04, New previousOrder, should be same as BUY EXECUTED: 164.49
# 2019-02-05, BUY EXECUTED, Price: 170.30, Cost: 1703.00, Comm 1.70
# 2019-02-25, BUY CREATE PYRAMID, current close price: 172.39
# 2019-02-25, N value: 3.48
# 2019-02-25, Pyramid: 1.00
# 2019-02-25, N buy in price: 172.04
# 2019-02-25, New previousOrder, should be same as BUY EXECUTED: 170.30
# 2019-02-26, BUY EXECUTED, Price: 171.87, Cost: 1718.70, Comm 1.72
# 2019-03-04, BUY CREATE PYRAMID, current close price: 173.99
# 2019-03-04, N value: 3.21
# 2019-03-04, Pyramid: 2.00
# 2019-03-04, N buy in price: 173.47
# 2019-03-04, New previousOrder, should be same as BUY EXECUTED: 171.87
# 2019-03-05, BUY EXECUTED, Price: 174.08, Cost: 1740.80, Comm 1.74
# 2019-03-11, BUY CREATE PYRAMID, current close price: 177.01
# 2019-03-11, N value: 3.06
# 2019-03-11, Pyramid: 3.00
# 2019-03-11, N buy in price: 175.61
# 2019-03-11, New previousOrder, should be same as BUY EXECUTED: 174.08
# 2019-03-12, BUY EXECUTED, Price: 178.10, Cost: 1781.00, Comm 1.78
# 2019-03-13, BUY CREATE PYRAMID, current close price: 179.79
# 2019-03-13, N value: 3.24
# 2019-03-13, Pyramid: 4.00
# 2019-03-13, N buy in price: 179.72
# 2019-03-13, New previousOrder, should be same as BUY EXECUTED: 178.10
# 2019-03-14, BUY EXECUTED, Price: 181.95, Cost: 1819.50, Comm 1.82
# 2019-05-10, SELL CREATE, 10 day low: 198.55
# 2019-05-10, exit low: 195.85
# 2019-05-13, SELL EXECUTED, Price: 186.44, Cost: 1734.65, Comm 1.86
# 2019-05-13, SELL CREATE, 10 day low: 195.85
# 2019-05-13, exit low: 184.46
# 2019-05-14, SELL EXECUTED, Price: 185.15, Cost: 1734.65, Comm 1.85
# 2019-05-20, SELL CREATE, 10 day low: 184.46
# 2019-05-20, exit low: 181.85
# 2019-05-21, SELL EXECUTED, Price: 183.97, Cost: 1734.65, Comm 1.84
# 2019-05-22, SELL CREATE, 10 day low: 181.85
# 2019-05-22, exit low: 181.54
# 2019-05-23, SELL EXECUTED, Price: 178.58, Cost: 1734.65, Comm 1.79
# 2019-05-23, SELL CREATE, 10 day low: 181.54
# 2019-05-23, exit low: 178.44
# 2019-05-24, SELL EXECUTED, Price: 178.98, Cost: 1734.65, Comm 1.79
# 2019-05-24, SELL CREATE, 10 day low: 178.44
# 2019-05-24, exit low: 177.76
# 2019-05-28, SELL EXECUTED, Price: 177.71, Cost: 1734.65, Comm 1.78
# 2019-05-28, OPERATION PROFIT, GROSS 500.40, NET 479.08
# 2019-06-11, BUY CREATE, 193.49
# 2019-06-11, entry high: 191.28
# 2019-06-12, BUY EXECUTED, Price: 192.64, Cost: 1926.40, Comm 1.93
# 2019-06-18, BUY CREATE PYRAMID, current close price: 197.11
# 2019-06-18, N value: 4.44
# 2019-06-18, Pyramid: 0.00
# 2019-06-18, N buy in price: 194.86
# 2019-06-18, New previousOrder, should be same as BUY EXECUTED: 192.64
# 2019-06-19, BUY EXECUTED, Price: 198.33, Cost: 1983.30, Comm 1.98
# 2019-07-02, BUY CREATE PYRAMID, current close price: 201.36
# 2019-07-02, N value: 4.15
# 2019-07-02, Pyramid: 1.00
# 2019-07-02, N buy in price: 200.41
# 2019-07-02, New previousOrder, should be same as BUY EXECUTED: 198.33
# 2019-07-03, BUY EXECUTED, Price: 201.90, Cost: 2019.00, Comm 2.02
# 2019-07-15, BUY CREATE PYRAMID, current close price: 203.82
# 2019-07-15, N value: 3.66
# 2019-07-15, Pyramid: 2.00
# 2019-07-15, N buy in price: 203.73
# 2019-07-15, New previousOrder, should be same as BUY EXECUTED: 201.90
# 2019-07-16, BUY EXECUTED, Price: 203.21, Cost: 2032.10, Comm 2.03
# 2019-07-22, BUY CREATE PYRAMID, current close price: 205.82
# 2019-07-22, N value: 3.46
# 2019-07-22, Pyramid: 3.00
# 2019-07-22, N buy in price: 204.94
# 2019-07-22, New previousOrder, should be same as BUY EXECUTED: 203.21
# 2019-07-23, BUY EXECUTED, Price: 207.05, Cost: 2070.50, Comm 2.07
# 2019-07-31, BUY CREATE PYRAMID, current close price: 211.60
# 2019-07-31, N value: 3.23
# 2019-07-31, Pyramid: 4.00
# 2019-07-31, N buy in price: 208.67
# 2019-07-31, New previousOrder, should be same as BUY EXECUTED: 207.05
# 2019-08-01, BUY EXECUTED, Price: 212.45, Cost: 2124.50, Comm 2.12
# 2019-08-05, SELL CREATE, 10 day low: 202.64
# 2019-08-05, exit low: 192.03
# 2019-08-06, SELL EXECUTED, Price: 194.98, Cost: 2025.97, Comm 1.95
# 2019-08-23, SELL CREATE, N stop: 202.25
# 2019-08-23, Current Price: 202.03
# 2019-08-23, N value: 4.78
# 2019-08-26, SELL EXECUTED, Price: 205.24, Cost: 2025.97, Comm 2.05
# 2019-12-03, SELL CREATE, 10 day low: 261.78
# 2019-12-03, exit low: 259.45
# 2019-12-04, SELL EXECUTED, Price: 261.07, Cost: 2025.97, Comm 2.61
# Final Portfolio Value: 102971.82
